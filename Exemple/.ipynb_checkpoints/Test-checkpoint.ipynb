# %% [markdown]
# # Test setvector3d object

# %%
import setvector3d.setvector3d as sv3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity

# %%
#uniform distribution of vector on a sphere see for explication : http://neilsloane.com/icosahedral.codes/
val=np.loadtxt('icover.3.10832.19.19.txt') 
dim=int(np.size(val)/3)
Vector=val.reshape([dim,3])

# %%
Vref=np.array([1,0,0])
angle=30.*np.pi/180.
lim=np.cos(angle)

ps=Vector[:,0]*Vref[0]+Vector[:,1]*Vref[1]+Vector[:,2]*Vref[2]
id=np.where(np.abs(ps)>lim)
v=sv3d.setvector3d(Vector[id[0],:])

# %%
v.stereoplot(contourf=False,bw=0.1,plotOT=True,nbpoints=0,projz=0,angle=np.array([30.,60.]))

# %%
v.stereoplot(contourf=False,bw=0.1,plotOT=True,nbpoints=0,projz=1,angle=np.array([30.,60.]))

# %%
v.stereoplot(contourf=True,bw=0.1,plotOT=True,nbpoints=0,projz=0,angle=np.array([30.,60.]))
# Out:
# Your array should have 3 columns X,Y,Z
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b0d1f2c36fc7> in <module>()
# ----> 1 v.stereoplot(contourf=True,bw=0.1,plotOT=True,nbpoints=0,projz=0,angle=np.array([30.,60.]))
#
# ~/anaconda3/lib/python3.7/site-packages/setvector3d/setvector3d.py in stereoplot(self, contourf, bw, plotOT, nbpoints, projz, angle, cm)
#     118             vcir=setvector3d(np.array([xcir,ycir,zcir]))
#     119
# --> 120             vtot=viso.concatenate(vcir)
#     121
#     122             phie,thetae=vtot.cart2spher()
#
# ~/anaconda3/lib/python3.7/site-packages/setvector3d/setvector3d.py in concatenate(self, v1)
#     245         '''
#     246
# --> 247         return setvector3d(np.concatenate((self.vector,v1.vector)))
#     248
#     249     def subset(self,nbpoints):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
v.stereoplot(contourf=True,bw=0.1,plotOT=True,nbpoints=0,projz=1,angle=np.array([30.,60.]))

# %%
val=sv3d.uni_dist.unidist

# %%
dim=int(np.size(val)/3)
xx=val.reshape([dim,3])
id=np.where(xx[:,2]>0)
xxuse=xx[id[0],:]
viso=sv3d.setvector3d(xxuse)

# %%
tot=1000
omega = np.linspace(0, 2*np.pi, tot)
zcir = np.zeros(tot)
xcir = np.cos(omega)
ycir = np.sin(omega)
