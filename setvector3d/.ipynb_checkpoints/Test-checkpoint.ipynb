# %% [markdown]
# # Test setvector3d object

# %%
import setvector3d
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity

# %%
#uniform distribution of vector on a sphere see for explication : http://neilsloane.com/icosahedral.codes/
val=np.loadtxt('icover.3.10832.19.19.txt') 
dim=int(np.size(val)/3)
Vector=val.reshape([dim,3])

# %%
Vref=np.array([0,0,1])
angle=15.*np.pi/180.
lim=np.cos(angle)

ps=Vector[:,0]*Vref[0]+Vector[:,1]*Vref[1]+Vector[:,2]*Vref[2]
id=np.where(np.abs(ps)>lim)

# %%
plt.hist(ps[id[0]])
# Out:
# (array([186.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 186.]),
#  array([-0.99980567, -0.79984454, -0.5998834 , -0.39992227, -0.19996113,
#          0.        ,  0.19996113,  0.39992227,  0.5998834 ,  0.79984454,
#          0.99980567]),
#  <a list of 10 Patch objects>)

# %%
lim
# Out:
# 0.9659258262890683

# %%
len(id[0])
# Out:
# 372

# %%
v=setvector3d.setvector3d(Vector)
# Out:
# Normalising vector length to 1

# %%
v.stereoplot(bw=0.1,nbpoints=0)
# Out:
# Normalising vector length to 1
# Normalising vector length to 1
# kde computed

# %%
v.stereoplot(contourf=1,bw=0.03,nbpoints=0)
# Out:
# Normalising vector length to 1
# Normalising vector length to 1
# kde computed
# Normalising vector length to 1
